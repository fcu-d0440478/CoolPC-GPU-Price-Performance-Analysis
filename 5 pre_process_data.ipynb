# %%
import sqlite3
import json
import pandas as pd

# %% [markdown]
# ## gpus前處理

# %%
# 連接到使用者上傳的 gpus.db
gpus_conn = sqlite3.connect('gpus.db')

# 讀取資料
df = pd.read_sql_query("SELECT * FROM gpus", gpus_conn)
df
# Out:
#       id                                 name  score
# 0      1        NVIDIA RTX PRO 6000 Blackwell  15814
# 1      2              NVIDIA GeForce RTX 5090  14469
# 2      3            NVIDIA GeForce RTX 5090 D  14417
# 3      4              NVIDIA GeForce RTX 4090   9230
# 4      5              NVIDIA GeForce RTX 5080   8749
# ..   ...                                  ...    ...
# 269  277  AMD Radeon Graphics (Granite Ridge)    129
# 270  278            NVIDIA GeForce GTX 750 Ti    123
# 271  279        AMD Radeon Graphics (Raphael)    122
# 272  280              NVIDIA GeForce GTX 1050    120
# 273  281    Intel UHD Graphics 770 (13th gen)     78
#
# [274 rows x 3 columns]

# %%
# 將 score 欄位轉為數值（有些可能是字串）
df['score'] = pd.to_numeric(df['score'], errors='coerce')

# 保留每個 name 的最高分數那筆資料
df_deduplicated = df.sort_values(by='score', ascending=False).drop_duplicates(subset='name', keep='first')

# 清空原始表並寫入去重後的資料
cursor = gpus_conn.cursor()
cursor.execute("DELETE FROM gpus")
gpus_conn.commit()

df_deduplicated.to_sql('gpus', gpus_conn, if_exists='append', index=False)
df_deduplicated
# Out:
#       id                                 name  score
# 0      1        NVIDIA RTX PRO 6000 Blackwell  15814
# 134  142              NVIDIA GeForce RTX 5090  14480
# 135  143            NVIDIA GeForce RTX 5090 D  14425
# 136  144              NVIDIA GeForce RTX 4090   9236
# 137  145              NVIDIA GeForce RTX 5080   8762
# ..   ...                                  ...    ...
# 128  136  AMD Radeon Graphics (Granite Ridge)    130
# 129  137            NVIDIA GeForce GTX 750 Ti    124
# 271  279        AMD Radeon Graphics (Raphael)    122
# 272  280              NVIDIA GeForce GTX 1050    120
# 132  140    Intel UHD Graphics 770 (13th gen)     78
#
# [135 rows x 3 columns]

# %% [markdown]
# ## gpu mapping表

# %%
# Step 1: Load GPU mapping checklist
with open("3 gpu_mapping_checklist.json", "r", encoding="utf-8") as f:
    mapping = json.load(f)
mapping
# Out:
# {'AMD R7 240 系列': None,
#  'AMD RX550': 'AMD Radeon RX 550',
#  'AMD RX5500XT': 'AMD Radeon RX 5500 XT',
#  'AMD RX560': None,
#  'AMD RX5600XT': 'AMD Radeon RX 5600 XT',
#  'AMD RX570': 'AMD Radeon RX 570',
#  'AMD RX5700': 'AMD Radeon RX 5700',
#  'AMD RX5700XT': 'AMD Radeon RX 5700 XT',
#  'AMD RX580': 'AMD Radeon RX 580',
#  'AMD RX590': 'AMD Radeon RX 590',
#  'AMD RX6400': 'AMD Radeon RX 6400',
#  'AMD RX6500XT': 'AMD Radeon RX 6500 XT',
#  'AMD RX6600': 'AMD Radeon RX 6600',
#  'AMD RX6600XT': 'AMD Radeon RX 6600 XT',
#  'AMD RX6650XT': 'AMD Radeon RX 6650 XT',
#  'AMD RX6700XT': 'AMD Radeon RX 6700 XT',
#  'AMD RX6750XT': 'AMD Radeon RX 6750 XT',
#  'AMD RX6800': 'AMD Radeon RX 6800',
#  'AMD RX6800 首批公版卡': 'AMD Radeon RX 6800',
#  'AMD RX6800XT': 'AMD Radeon RX 6800 XT',
#  'AMD RX6800XT 首批公版卡': 'AMD Radeon RX 6800 XT',
#  'AMD RX6900XT': 'AMD Radeon RX 6900 XT',
#  'AMD RX6950XT': 'AMD Radeon RX 6950 XT',
#  'AMD Radeon 550 系列': 'AMD Radeon RX 550',
#  'AMD Radeon RX 550 系列': 'AMD Radeon RX 550',
#  'AMD Radeon RX7600-8G': 'AMD Radeon RX 7600',
#  'AMD Radeon RX7600XT OC 16G': 'AMD Radeon RX 7600',
#  'AMD Radeon RX7650GRE-8G': 'AMD Radeon RX 7650 GRE',
#  'AMD Radeon RX7700XT-12G': 'AMD Radeon RX 7700 XT',
#  'AMD Radeon RX7700XT-12G(9/6晚上9點開賣)': 'AMD Radeon RX 7700 XT',
#  'AMD Radeon RX7800XT-16G': 'AMD Radeon RX 7800 XT',
#  'AMD Radeon RX7800XT-16G(9/6晚上9點開賣)': 'AMD Radeon RX 7800 XT',
#  'AMD Radeon RX7900GRE-16G': 'AMD Radeon RX 7900 GRE',
#  'AMD Radeon RX7900XT-20G': 'AMD Radeon RX 7900 GRE',
#  'AMD Radeon RX7900XTX-24G': 'AMD Radeon RX 7900 GRE',
#  'AMD Radeon RX9060XT-16G': 'AMD Radeon RX 9060 XT 16 GB',
#  'AMD Radeon RX9060XT-8G': 'AMD Radeon RX 9060 XT',
#  'AMD Radeon RX9070-16G': 'AMD Radeon RX 9070',
#  'AMD Radeon RX9070GRE-12G': 'AMD Radeon RX 9070',
#  'AMD Radeon RX9070XT-16G': 'AMD Radeon RX 9070',
#  'AMD 專業級/工作站級 顯卡': None,
#  'AMD 工作站繪圖卡': None,
#  'AMD 工作站繪圖卡 (客訂交貨.歡迎議價)': None,
#  'INTEL ARC 顯示卡': None,
#  'INTEL Arc A770 顯示卡': 'Intel Arc A770',
#  'INTEL Arc B570': 'Intel Arc B570',
#  'INTEL Arc B570 顯示卡': 'Intel Arc B570',
#  'INTEL Arc B580': 'Intel Arc B580',
#  'INTEL Arc B580 顯示卡': 'Intel Arc B580',
#  'NVIDIA / AMD 外接式顯卡轉接盒': None,
#  'NVIDIA / AMD 外接顯卡轉接盒 (需另購顯卡)': None,
#  'NVIDIA / AMD 顯示卡周邊配件': None,
#  'NVIDIA GT1030': None,
#  'NVIDIA GT710': None,
#  'NVIDIA GT730': None,
#  'NVIDIA GTX1050': 'NVIDIA GeForce GTX 1050',
#  'NVIDIA GTX1050 3G': 'NVIDIA GeForce GTX 1050',
#  'NVIDIA GTX1050Ti': 'NVIDIA GeForce GTX 1050 Ti',
#  'NVIDIA GTX1060': 'NVIDIA GeForce GTX 1060-3GB',
#  'NVIDIA GTX1630 (DDR6)': None,
#  'NVIDIA GTX1650': 'NVIDIA GeForce GTX 1650',
#  'NVIDIA GTX1650 (DDR6)': 'NVIDIA GeForce GTX 1650',
#  'NVIDIA GTX1650 SUPER (DDR6)': 'NVIDIA GeForce GTX 1650 SUPER',
#  'NVIDIA GTX1660 (DDR5)': 'NVIDIA GeForce GTX 1660',
#  'NVIDIA GTX1660 SUPER (DDR6)': 'NVIDIA GeForce GTX 1660 SUPER',
#  'NVIDIA GTX1660Ti': 'NVIDIA GeForce GTX 1660 Ti',
#  'NVIDIA GTX1660Ti (無類比輸出)': 'NVIDIA GeForce GTX 1660 Ti',
#  'NVIDIA GeForce 210': None,
#  'NVIDIA Quadro 專業繪圖卡': 'NVIDIA Quadro M4000',
#  'NVIDIA Quadro 專業繪圖卡 (歡迎議價)': 'NVIDIA Quadro RTX A6000',
#  'NVIDIA RTX2060': 'NVIDIA GeForce RTX 2060',
#  'NVIDIA RTX2060 SUPER': 'NVIDIA GeForce RTX 2060 SUPER',
#  'NVIDIA RTX2060(12G)': 'NVIDIA GeForce RTX 2060 12 GB',
#  'NVIDIA RTX2060-12G': 'NVIDIA GeForce RTX 2060 12 GB',
#  'NVIDIA RTX2060-6G': 'NVIDIA GeForce RTX 2060',
#  'NVIDIA RTX2070': 'NVIDIA GeForce RTX 2070',
#  'NVIDIA RTX2070 SUPER': 'NVIDIA GeForce RTX 2070 SUPER',
#  'NVIDIA RTX2080': 'NVIDIA GeForce RTX 2080',
#  'NVIDIA RTX2080 SUPER': 'NVIDIA GeForce RTX 2080 SUPER',
#  'NVIDIA RTX2080Ti': 'NVIDIA GeForce RTX 2080 Ti',
#  'NVIDIA RTX3050-6GB': 'NVIDIA GeForce RTX 3050 6 GB',
#  'NVIDIA RTX3050-8G': 'NVIDIA GeForce RTX 3050',
#  'NVIDIA RTX3050-8GB': 'NVIDIA GeForce RTX 3050',
#  'NVIDIA RTX3060': 'NVIDIA GeForce RTX 3060',
#  'NVIDIA RTX3060-12G': 'NVIDIA GeForce RTX 3060',
#  'NVIDIA RTX3060-12GB': 'NVIDIA GeForce RTX 3060',
#  'NVIDIA RTX3060-8G': 'NVIDIA GeForce RTX 3060 8 GB',
#  'NVIDIA RTX3060-8GB': 'NVIDIA GeForce RTX 3060 8 GB',
#  'NVIDIA RTX3060TI': 'NVIDIA GeForce RTX 3060 Ti',
#  'NVIDIA RTX3060TI-8G': 'NVIDIA GeForce RTX 3060',
#  'NVIDIA RTX3060TI-8G(GDDR6)': 'NVIDIA GeForce RTX 3060',
#  'NVIDIA RTX3060TI-8G(GDDR6X)': 'NVIDIA GeForce RTX 3060',
#  'NVIDIA RTX3070': 'NVIDIA GeForce RTX 3070',
#  'NVIDIA RTX3070 Ti': 'NVIDIA GeForce RTX 3070 Ti',
#  'NVIDIA RTX3080': 'NVIDIA GeForce RTX 3080',
#  'NVIDIA RTX3080 Ti': 'NVIDIA GeForce RTX 3080 Ti',
#  'NVIDIA RTX3080 零星到貨! 隨時開放': 'NVIDIA GeForce RTX 3080',
#  'NVIDIA RTX3080(10G)': 'NVIDIA GeForce RTX 3080',
#  'NVIDIA RTX3080(12G)': 'NVIDIA GeForce RTX 3080 12 GB',
#  'NVIDIA RTX3080-10G': 'NVIDIA GeForce RTX 3080',
#  'NVIDIA RTX3080-12G': 'NVIDIA GeForce RTX 3080 12 GB',
#  'NVIDIA RTX3090': 'NVIDIA GeForce RTX 3090',
#  'NVIDIA RTX3090 Ti': 'NVIDIA GeForce RTX 3090 Ti',
#  'NVIDIA RTX3090 零星到貨! 隨時開放': 'NVIDIA GeForce RTX 3090',
#  'NVIDIA RTX4060-8G': 'NVIDIA GeForce RTX 4060',
#  'NVIDIA RTX4060-8GB': 'NVIDIA GeForce RTX 4060',
#  'NVIDIA RTX4060Ti-16G': 'NVIDIA GeForce RTX 4060 Ti 16 GB',
#  'NVIDIA RTX4060Ti-8G': 'NVIDIA GeForce RTX 4060 Ti 8 GB',
#  'NVIDIA RTX4060Ti-8GB': 'NVIDIA GeForce RTX 4060 Ti 8 GB',
#  'NVIDIA RTX4070 SUPER 12GB': 'NVIDIA GeForce RTX 4070',
#  'NVIDIA RTX4070 SUPER 12GB(1/17晚上10點開賣)': 'NVIDIA GeForce RTX 4070',
#  'NVIDIA RTX4070-12G': 'NVIDIA GeForce RTX 4070',
#  'NVIDIA RTX4070-12GB': 'NVIDIA GeForce RTX 4070',
#  'NVIDIA RTX4070-12GB (GDDR6)': 'NVIDIA GeForce RTX 4070',
#  'NVIDIA RTX4070-12GB (GDDR6X)': 'NVIDIA GeForce RTX 4070',
#  'NVIDIA RTX4070TI-12G': 'NVIDIA GeForce RTX 4070',
#  'NVIDIA RTX4070TI-12GB': 'NVIDIA GeForce RTX 4070',
#  'NVIDIA RTX4070Ti 12GB': 'NVIDIA GeForce RTX 4070',
#  'NVIDIA RTX4070Ti SUPER 16GB': 'NVIDIA GeForce RTX 4070',
#  'NVIDIA RTX4080 SUPER 16GB': 'NVIDIA GeForce RTX 4080',
#  'NVIDIA RTX4080-16G': 'NVIDIA GeForce RTX 4080',
#  'NVIDIA RTX4080-16G [11/16 10PM 開賣]': 'NVIDIA GeForce RTX 4080',
#  'NVIDIA RTX4080-16GB': 'NVIDIA GeForce RTX 4080',
#  'NVIDIA RTX4090': 'NVIDIA GeForce RTX 4090',
#  'NVIDIA RTX5050-8GB(GDDR6)': 'NVIDIA GeForce RTX 5050',
#  'NVIDIA RTX5060-8GB(GDDR7)': 'NVIDIA GeForce RTX 5060',
#  'NVIDIA RTX5060Ti-16GB(GDDR7)': 'NVIDIA GeForce RTX 5060 Ti 16 GB',
#  'NVIDIA RTX5060Ti-8GB(GDDR7)': 'NVIDIA GeForce RTX 5060',
#  'NVIDIA RTX5070-12GB(GDDR7)': 'NVIDIA GeForce RTX 5070',
#  'NVIDIA RTX5070-12GB(GDDR7) 3/5-10點開賣': 'NVIDIA GeForce RTX 5070',
#  'NVIDIA RTX5070Ti-16GB(GDDR7)': 'NVIDIA GeForce RTX 5070',
#  'NVIDIA RTX5070Ti-16GB(GDDR7)-2/20晚上10點開賣': 'NVIDIA GeForce RTX 5070',
#  'NVIDIA RTX5080-16GB(GDDR7)': 'NVIDIA GeForce RTX 5080',
#  'NVIDIA RTX5090-16GB(GDDR7) 年節期間現貨+預定皆已完售！': 'NVIDIA GeForce RTX 5090',
#  'NVIDIA RTX5090-32GB(GDDR7)': 'NVIDIA GeForce RTX 5090',
#  'NVIDIA RTX5090-32GB(GDDR7) 年節期間現貨+預定皆已完售！': 'NVIDIA GeForce RTX 5090',
#  'NVIDIA 外接式顯卡轉接盒': None,
#  'NVIDIA 專業繪圖卡': 'NVIDIA Quadro RTX A6000',
#  '微星 RX6600XT MECH 2X 8G V1(2589MHz/21.5cm/註四年)*參考價$13490': 'AMD Radeon RX 6600'}

# %% [markdown]
# ## VGA前處理

# %%
# Step 2: Connect to vga.db and update schema
vga_conn = sqlite3.connect("vga.db")
vga_cursor = vga_conn.cursor()

# %%
# Step 3: Update pure_chipset column based on mapping
vga_cursor.execute("SELECT rowid, chipset FROM vga")
rows = vga_cursor.fetchall()

# %%
for rowid, chipset in rows:
    pure_chipset = mapping.get(chipset)
    vga_cursor.execute(
        "UPDATE vga SET pure_chipset = ? WHERE rowid = ?", (pure_chipset, rowid)
    )

vga_conn.commit()

# %%
gpus_df = pd.read_sql_query("SELECT name, score FROM gpus", gpus_conn)
gpus_df
# Out:
#                               name  score
# 0    NVIDIA RTX PRO 6000 Blackwell  15814
# 1            AMD Radeon RX 9070 XT   7251
# 2           AMD Radeon RX 7900 XTX   6838
# 3               AMD Radeon RX 9070   6283
# 4            AMD Radeon RX 7900 XT   5618
# ..                             ...    ...
# 130        NVIDIA GeForce GTX 1650    327
# 131          AMD Radeon RX 6500 XT    249
# 132    AMD Radeon Vega 7 (Cezanne)    225
# 133  AMD Radeon Graphics (Raphael)    122
# 134        NVIDIA GeForce GTX 1050    120
#
# [135 rows x 2 columns]

# %%
# Step 5: Update score column in vga table
for _, row in gpus_df.iterrows():
    name, score = row["name"], row["score"]
    vga_cursor.execute("UPDATE vga SET score = ? WHERE pure_chipset = ?", (score, name))

vga_conn.commit()

# %%
# Compute CP = score / price
vga_cursor.execute(
    """
    UPDATE vga
    SET CP = CASE
        WHEN score IS NOT NULL AND price IS NOT NULL AND price != 0 THEN CAST(score AS REAL) / price
        ELSE NULL
    END
"""
)
vga_conn.commit()

# %%
# 查看刪除前的總筆數
vga_cursor.execute("SELECT COUNT(*) FROM vga")
print(f"刪除前總筆數: {vga_cursor.fetchone()[0]}")

# 刪除 pure_chipset 為 NULL 的資料
vga_cursor.execute("DELETE FROM vga WHERE pure_chipset IS NULL")
vga_conn.commit()

# 查看刪除後的總筆數
vga_cursor.execute("SELECT COUNT(*) FROM vga")
print(f"刪除後總筆數: {vga_cursor.fetchone()[0]}")
# Out:
# 刪除前總筆數: 101558
# 刪除後總筆數: 83203

# %%
# Step 6: Output updated vga table
vga_updated_df = pd.read_sql_query("SELECT * FROM vga", vga_conn)
vga_updated_df
# Out:
#            date                  chipset  \
# 0      20200105        NVIDIA GTX1050 3G
# 1      20200105        NVIDIA GTX1050 3G
# 2      20200105         NVIDIA GTX1050Ti
# 3      20200105         NVIDIA GTX1050Ti
# 4      20200105         NVIDIA GTX1050Ti
# ...         ...                      ...
# 83198  20251118  AMD Radeon RX9070XT-16G
# 83199  20251118  AMD Radeon RX9070XT-16G
# 83200  20251118  AMD Radeon RX9070XT-16G
# 83201  20251118  AMD Radeon RX9070XT-16G
# 83202  20251118  AMD Radeon RX9070XT-16G
#
#                                                  product  price  \
# 0              微星 GTX1050 3GT OC飆風(1582MHz/雙/21.5cm/註四年)   4390
# 1      EVGA GTX1050 3GB SC GAMING(1455MHz/單風/14.5cm/6...   4290
# 2          華碩 PH-GTX1050TI-4G鳳凰版(1392MHz/19.2cm/單風扇/註四年)   3990
# 3         微星 GTX1050Ti AERO 4G OC(1455MHz/15.5cm/單風扇註四年)   3990
# 4             技嘉 GTX1050Ti D5 4G(1392MHz/17.2cm/單風扇/註四年)   3990
# ...                                                  ...    ...
# 83198  撼訊 RX9070XT 16G-A 遊蕩者(2970MHz/31cm/三風扇/三年保)*MI...  22990
# 83199  撼訊 RX9070XT 16G-L/OC 暗黑犬(3010MHz/34cm/三風扇/註四年)...  24990
# 83200  撼訊 RX9070XT 16G-L/OC/WHITE 暗黑犬(白)(3010MHz/34cm...  25490
# 83201  撼訊 RX9070XT 16G-L/OC/REVA 夜嵐紀念版(3010MHz/35cm/三...  25490
# 83202  撼訊 RX9070XT 16G-E/OC 紅魔(3060MHz/36cm/三風扇/註五年)*...  25990
#
#                      pure_chipset   score        CP
# 0         NVIDIA GeForce GTX 1050   120.0  0.027335
# 1         NVIDIA GeForce GTX 1050   120.0  0.027972
# 2      NVIDIA GeForce GTX 1050 Ti   305.0  0.076441
# 3      NVIDIA GeForce GTX 1050 Ti   305.0  0.076441
# 4      NVIDIA GeForce GTX 1050 Ti   305.0  0.076441
# ...                           ...     ...       ...
# 83198          AMD Radeon RX 9070  6283.0  0.273293
# 83199          AMD Radeon RX 9070  6283.0  0.251421
# 83200          AMD Radeon RX 9070  6283.0  0.246489
# 83201          AMD Radeon RX 9070  6283.0  0.246489
# 83202          AMD Radeon RX 9070  6283.0  0.241747
#
# [83203 rows x 7 columns]

# %%
vga_df = pd.read_sql_query("SELECT * FROM vga", vga_conn)

# %%
# Define extended exclusion keywords for chipset
chipset_exclude_keywords = [
    'AMD 工作站繪圖卡 (客訂交貨.歡迎議價)',
    'NVIDIA / AMD 外接顯卡轉接盒 (需另購顯卡)',
    'NVIDIA / AMD 顯示卡周邊配件',
    'NVIDIA Quadro 專業繪圖卡 (歡迎議價)',
    'NVIDIA / AMD 外接式顯卡轉接盒',
    'NVIDIA Quadro 專業繪圖卡',
    'NVIDIA 外接式顯卡轉接盒',
    'AMD 工作站繪圖卡'
]

# Re-apply filtering
product_exclude_keywords = [
    '贈', '抽', '送', '加購', '登錄', '活動', '限量', '現省',
    '現折', '現賺', '再加', '加送', '加價購', '送ROG', '延長線'
]

# %%
product_mask = ~vga_df['product'].astype(str).apply(
    lambda p: any(keyword in p for keyword in product_exclude_keywords)
)
chipset_mask = ~vga_df['chipset'].astype(str).apply(
    lambda c: any(keyword in c for keyword in chipset_exclude_keywords)
)

# %%
# Apply filter and sort
filtered_df = vga_df[product_mask & chipset_mask].sort_values(by='CP', ascending=False)
filtered_df
# Out:
#            date                     chipset  \
# 80285  20250815  NVIDIA RTX5070-12GB(GDDR7)
# 80529  20250817  NVIDIA RTX5070-12GB(GDDR7)
# 80040  20250808  NVIDIA RTX5070-12GB(GDDR7)
# 81200  20250917   NVIDIA RTX5050-8GB(GDDR6)
# 81487  20250924   NVIDIA RTX5050-8GB(GDDR6)
# ...         ...                         ...
# 83137  20251118                NVIDIA 專業繪圖卡
# 83138  20251118                NVIDIA 專業繪圖卡
# 83139  20251118                NVIDIA 專業繪圖卡
# 83140  20251118                NVIDIA 專業繪圖卡
# 83141  20251118                NVIDIA 專業繪圖卡
#
#                                                  product   price  \
# 80285  [合購] INNO3D RTX5070 TWIN X2 OC 合購 金士頓 KC3000 5...     888
# 80529  [合購] INNO3D RTX5070 TWIN X2 OC 合購 金士頓 KC3000 5...     888
# 80040  [合購] INNO3D RTX5070 TWIN X2 OC 合購 金士頓 KC3000 5...     888
# 81200  [紅包500] 買技嘉 RTX5050顯卡+購 GP-P650G(650W)金牌電源(原價2...    1990
# 81487  [紅包500] 買技嘉 RTX5050顯卡+購 GP-P650G(650W)金牌電源(原價2...    1990
# ...                                                  ...     ...
# 83137  麗臺 NVIDIA RTX 6000 Ada(48GB GDDR6 ECC/26.67cm/...  299000
# 83138  麗臺 NVIDIA RTX A400(4G GDDR6 64bit/CUDA:768/16....    6400
# 83139  麗臺 NVIDIA RTX A1000(8G GDDR6 128bit/CUDA:2304/...   15300
# 83140  麗臺 NVIDIA RTX PRO 6000 Blackwell Max-Q 96GB GD...  329000
# 83141  麗臺 NVIDIA RTX PRO 6000 Blackwell 96GB GDDR7 工作...  339000
#
#                   pure_chipset   score        CP
# 80285  NVIDIA GeForce RTX 5070  5256.0  5.918919
# 80529  NVIDIA GeForce RTX 5070  5256.0  5.918919
# 80040  NVIDIA GeForce RTX 5070  5256.0  5.918919
# 81200  NVIDIA GeForce RTX 5050  2317.0  1.164322
# 81487  NVIDIA GeForce RTX 5050  2317.0  1.164322
# ...                        ...     ...       ...
# 83137  NVIDIA Quadro RTX A6000     NaN       NaN
# 83138  NVIDIA Quadro RTX A6000     NaN       NaN
# 83139  NVIDIA Quadro RTX A6000     NaN       NaN
# 83140  NVIDIA Quadro RTX A6000     NaN       NaN
# 83141  NVIDIA Quadro RTX A6000     NaN       NaN
#
# [73070 rows x 7 columns]

# %%
filtered_df = filtered_df[
    filtered_df['pure_chipset'].notnull() & 
    (filtered_df['pure_chipset'].str.strip() != '')
]

filtered_df = filtered_df[
    filtered_df['score'].notnull() & 
    (filtered_df['score'] != '')
]

# %%
filtered_df
# Out:
#            date                     chipset  \
# 80285  20250815  NVIDIA RTX5070-12GB(GDDR7)
# 80529  20250817  NVIDIA RTX5070-12GB(GDDR7)
# 80040  20250808  NVIDIA RTX5070-12GB(GDDR7)
# 81200  20250917   NVIDIA RTX5050-8GB(GDDR6)
# 81487  20250924   NVIDIA RTX5050-8GB(GDDR6)
# ...         ...                         ...
# 45287  20220404       NVIDIA GTX1650 (DDR6)
# 44956  20220329       NVIDIA GTX1650 (DDR6)
# 45622  20220406       NVIDIA GTX1650 (DDR6)
# 44629  20220327       NVIDIA GTX1650 (DDR6)
# 45956  20220407       NVIDIA GTX1650 (DDR6)
#
#                                                  product  price  \
# 80285  [合購] INNO3D RTX5070 TWIN X2 OC 合購 金士頓 KC3000 5...    888
# 80529  [合購] INNO3D RTX5070 TWIN X2 OC 合購 金士頓 KC3000 5...    888
# 80040  [合購] INNO3D RTX5070 TWIN X2 OC 合購 金士頓 KC3000 5...    888
# 81200  [紅包500] 買技嘉 RTX5050顯卡+購 GP-P650G(650W)金牌電源(原價2...   1990
# 81487  [紅包500] 買技嘉 RTX5050顯卡+購 GP-P650G(650W)金牌電源(原價2...   1990
# ...                                                  ...    ...
# 45287   技嘉 GTX1650 D6 4G(1590MHz/17.2cm/單風扇) *參考價 $ 6390  99999
# 44956   技嘉 GTX1650 D6 4G(1590MHz/17.2cm/單風扇) *參考價 $ 6390  99999
# 45622   技嘉 GTX1650 D6 4G(1590MHz/17.2cm/單風扇) *參考價 $ 6390  99999
# 44629   技嘉 GTX1650 D6 4G(1590MHz/17.2cm/單風扇) *參考價 $ 6390  99999
# 45956   技嘉 GTX1650 D6 4G(1590MHz/17.2cm/單風扇) *參考價 $ 6390  99999
#
#                   pure_chipset   score        CP
# 80285  NVIDIA GeForce RTX 5070  5256.0  5.918919
# 80529  NVIDIA GeForce RTX 5070  5256.0  5.918919
# 80040  NVIDIA GeForce RTX 5070  5256.0  5.918919
# 81200  NVIDIA GeForce RTX 5050  2317.0  1.164322
# 81487  NVIDIA GeForce RTX 5050  2317.0  1.164322
# ...                        ...     ...       ...
# 45287  NVIDIA GeForce GTX 1650   327.0  0.003270
# 44956  NVIDIA GeForce GTX 1650   327.0  0.003270
# 45622  NVIDIA GeForce GTX 1650   327.0  0.003270
# 44629  NVIDIA GeForce GTX 1650   327.0  0.003270
# 45956  NVIDIA GeForce GTX 1650   327.0  0.003270
#
# [73044 rows x 7 columns]

# %%
# Save to new filtered_df.db
new_conn = sqlite3.connect("filtered_df.db")
filtered_df.to_sql("filtered_df", new_conn, if_exists="replace", index=False)
new_conn.commit()
new_conn.close()
