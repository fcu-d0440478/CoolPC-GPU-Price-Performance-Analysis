# %%
import sqlite3
import json
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## CP值最高的10筆資料

# %%
# 讀取 filtered_df 資料表
conn = sqlite3.connect("filtered_df.db")
df = pd.read_sql_query("SELECT * FROM filtered_df", conn)

# 轉換日期欄位格式
df["date"] = pd.to_datetime(df["date"], format="%Y%m%d")

# 篩選出最新日期的資料
latest_date = df["date"].max()
latest_df = df[df["date"] == latest_date]

# %%
# 依照 CP 值排序取前10名
top_10_cp = latest_df.sort_values(by="CP", ascending=False).head(10)
top_10_cp
# Out:
#           date                  chipset  \
# 47  2025-06-04       INTEL Arc B570 顯示卡
# 83  2025-06-04       INTEL Arc B580 顯示卡
# 140 2025-06-04       INTEL Arc B580 顯示卡
# 160 2025-06-04  AMD Radeon RX9070XT-16G
# 200 2025-06-04  AMD Radeon RX9070XT-16G
# 228 2025-06-04    AMD Radeon RX9070-16G
# 244 2025-06-04  AMD Radeon RX9070XT-16G
# 284 2025-06-04       INTEL Arc B580 顯示卡
# 300 2025-06-04       INTEL Arc A770 顯示卡
# 339 2025-06-04  AMD Radeon RX9070XT-16G
#
#                                                product  price  \
# 47   Acer Nitro Intel ARC B570 OC 10GB(2690MHz/27cm...   7690
# 83       INTEL 原廠 ARC B580 12G(2670MHz/27.2cm/雙風扇/三年保)   8990
# 140  華擎 ARC B580 Challenger 12G OC(2740MHz/25cm/雙風扇...   9290
# 160  ACER NITRO RX9070XT 16G OC(3100MHz/30cm/三風扇)極缺...  22990
# 200  技嘉 RX9070XT GAMING 16G(2970MHz/29cm/五年保)極缺！不收網...  22990
# 228  技嘉 RX9070 GAMING OC 16G(2700MHz/29cm/三風扇)極缺！不收...  19990
# 244  技嘉 RX9070XT GAMING OC 16G(3060MHz/29cm/五年保)極缺！...  23990
# 284  華擎 ARC B580 Steel Legend 12G OC(2800MHz/30cm/三...  10290
# 300  ACER 宏?? Predator Arc A770 16G(2400MHz/27cm/三年...   9990
# 339  撼訊 RX9070XT 16G-L/OC 暗黑犬(3010MHz/34cm/三風扇)極缺！不...  24990
#
#               pure_chipset   score        CP
# 47          Intel Arc B570  2649.0  0.344473
# 83          Intel Arc B580  3068.0  0.341268
# 140         Intel Arc B580  3068.0  0.330248
# 160  AMD Radeon RX 9070 XT  7260.0  0.315789
# 200  AMD Radeon RX 9070 XT  7260.0  0.315789
# 228     AMD Radeon RX 9070  6290.0  0.314657
# 244  AMD Radeon RX 9070 XT  7260.0  0.302626
# 284         Intel Arc B580  3068.0  0.298154
# 300         Intel Arc A770  2969.0  0.297197
# 339  AMD Radeon RX 9070 XT  7260.0  0.290516

# %%
# 設定圖表大小與字體
plt.rcParams["font.family"] = "Microsoft JhengHei"  # 或 "SimHei" / "標楷體" 等
plt.rcParams["font.size"] = 10

# %%
# 圖1: Top 10 顯卡的 CP 值長條圖
plt.figure(figsize=(12, 6))
plt.barh(top_10_cp["product"], top_10_cp["CP"], color='skyblue')
plt.xlabel("CP 值 (score / price)")
plt.title("Top 10 CP 值顯卡（2025-06-04）")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
# 畫圖：使用 "hot" 配色的 2D 直方熱點圖
plt.figure(figsize=(10, 6))
plt.hist2d(
    latest_df["price"],
    latest_df["score"],
    bins=50,
    cmap="hot"
)
plt.colorbar(label="資料密度")
plt.title("顯卡價格 vs 分數 分布熱點圖（紅黃配色）")
plt.xlabel("價格")
plt.ylabel("分數")
plt.tight_layout()
plt.show()

# %%
import numpy as np

# 建立 2D 直方圖並取得數值資料
plt.figure(figsize=(12, 6))
counts, xedges, yedges, im = plt.hist2d(
    latest_df["price"],
    latest_df["score"],
    bins=50,
    cmap="hot"
)

# 加上 colorbar
plt.colorbar(label="資料密度")

# 加上文字標註每個格子的 count 數量（只顯示非 0）
for i in range(len(xedges) - 1):
    for j in range(len(yedges) - 1):
        count = int(counts[i, j])
        if count > 0:
            plt.text(
                (xedges[i] + xedges[i+1]) / 2,
                (yedges[j] + yedges[j+1]) / 2,
                str(count),
                ha='center',
                va='center',
                fontsize=7,
                color='white'
            )

plt.title("顯卡價格 vs 分數 分布熱點圖（含密度數字標註）")
plt.xlabel("價格")
plt.ylabel("分數")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 發現有離群值資料

# %%
# 依照 CP 值排序取前10名
top_10_price = latest_df.sort_values(by="price", ascending=False).head(10)
top_10_price
# Out:
#             date                     chipset  \
# 43345 2025-06-04  NVIDIA RTX5090-32GB(GDDR7)
# 40450 2025-06-04  NVIDIA RTX5090-32GB(GDDR7)
# 39388 2025-06-04  NVIDIA RTX5090-32GB(GDDR7)
# 38888 2025-06-04  NVIDIA RTX5090-32GB(GDDR7)
# 38868 2025-06-04  NVIDIA RTX5090-32GB(GDDR7)
# 37346 2025-06-04  NVIDIA RTX5090-32GB(GDDR7)
# 36313 2025-06-04  NVIDIA RTX5090-32GB(GDDR7)
# 36286 2025-06-04  NVIDIA RTX5090-32GB(GDDR7)
# 36276 2025-06-04  NVIDIA RTX5090-32GB(GDDR7)
# 35122 2025-06-04  NVIDIA RTX5090-32GB(GDDR7)
#
#                                                  product   price  \
# 43345  華碩 ROG-ASTRAL-LC-RTX5090-O32G-GAMING(2610MHz/2...  109990
# 40450  華碩 ROG-ASTRAL-RTX5090-O32G-GAMING(2610MHz/36cm...  105990
# 39388  微星 RTX5090 32G SUPRIM LIQUID SOC(2580MHz/28cm/...  103990
# 38888  技嘉 AORUS RTX5090 XTREME WATERFORCE 32G(水冷)詳情請門市洽詢  102990
# 38868  技嘉 AORUS RTX5090 XTREME WATERFORCE WB 32G(開放式水...  102990
# 37346  技嘉 AORUS RTX5090 MASTER ICE 32G(2655MHz/36cm)極...  100990
# 36313  華碩 TUF-RTX5090-O32G-GAMING(2580MHz/35cm/三風扇/註冊...   99990
# 36286  技嘉 AORUS RTX5090 MASTER 32G(2655MHz/36cm)極缺！暫不...   99990
# 36276  微星 RTX5090 32G SUPRIM SOC(2580MHz/36cm/三風扇)極缺！...   99990
# 35122  微星 RTX5090 32G VANGUARD SOC(2527MHz/36cm/三風扇/註...   98990
#
#                   pure_chipset    score        CP
# 43345  NVIDIA GeForce RTX 5090  14411.0  0.131021
# 40450  NVIDIA GeForce RTX 5090  14411.0  0.135966
# 39388  NVIDIA GeForce RTX 5090  14411.0  0.138581
# 38888  NVIDIA GeForce RTX 5090  14411.0  0.139926
# 38868  NVIDIA GeForce RTX 5090  14411.0  0.139926
# 37346  NVIDIA GeForce RTX 5090  14411.0  0.142697
# 36313  NVIDIA GeForce RTX 5090  14411.0  0.144124
# 36286  NVIDIA GeForce RTX 5090  14411.0  0.144124
# 36276  NVIDIA GeForce RTX 5090  14411.0  0.144124
# 35122  NVIDIA GeForce RTX 5090  14411.0  0.145580

# %%
timeseries_df = df[df["score"].notna()].copy()

# 按日期統計平均價格、分數、CP值與樣本數
daily_stats = timeseries_df.groupby("date").agg(
    avg_price=("price", "mean"),
    avg_score=("score", "mean"),
    avg_cp=("CP", "mean"),
    count=("price", "count")
).reset_index()

# %%
daily_stats
# Out:
#           date     avg_price    avg_score    avg_cp  count
# 0   2020-01-05  14077.432836  1712.203980  0.128691    201
# 1   2020-01-07  14070.020000  1714.090000  0.128916    200
# 2   2020-01-09  14216.905941  1732.336634  0.129036    202
# 3   2020-01-10  14173.916256  1728.886700  0.129282    203
# 4   2020-01-12  14123.844221  1713.944724  0.128926    199
# ..         ...           ...          ...       ...    ...
# 403 2025-04-30  36166.468085  6703.113475  0.204286    141
# 404 2025-05-07  36182.780142  6698.404255  0.204279    141
# 405 2025-05-11  35619.328767  6618.513699  0.204945    146
# 406 2025-05-22  35533.219858  6632.134752  0.207036    141
# 407 2025-06-04  36149.597015  6707.059701  0.207045    134
#
# [408 rows x 5 columns]

# %%
# 畫圖1：平均價格與分數
plt.figure(figsize=(12, 6))
plt.plot(daily_stats["date"], daily_stats["avg_price"], marker='o', label="平均價格")
plt.plot(daily_stats["date"], daily_stats["avg_score"], marker='x', label="平均分數")
plt.title("跨日顯卡市場趨勢分析：價格與效能")
plt.xlabel("日期")
plt.ylabel("值")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# 畫圖2：CP 值趨勢
plt.figure(figsize=(12, 4))
plt.plot(daily_stats["date"], daily_stats["avg_cp"], marker='s', color='green', label="平均 CP 值")
plt.title("跨日顯卡市場趨勢分析：平均 CP 值")
plt.xlabel("日期")
plt.ylabel("CP 值")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# 取出要聚類的欄位
clustering_df = df[["price", "score"]].copy()

# 標準化處理
scaler = StandardScaler()
scaled_data = scaler.fit_transform(clustering_df)

# 建立並執行 KMeans 模型（分為 3 群）
kmeans = KMeans(n_clusters=4, random_state=42, n_init=10)
clustering_df["cluster"] = kmeans.fit_predict(scaled_data)

# 將分群結果合併回原資料（可選）
df_with_cluster = df.copy()
df_with_cluster["cluster"] = clustering_df["cluster"]

# 畫圖展示分群結果
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=clustering_df,
    x="price",
    y="score",
    hue="cluster",
    palette="Set1"
)
plt.title("顯卡價格與分數的 KMeans 聚類分析")
plt.xlabel("價格")
plt.ylabel("分數")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
conn.close()
